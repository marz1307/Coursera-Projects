# %% [markdown]
# <a href="https://colab.research.google.com/github/marz1307/Coursera-Projects/blob/main/Working_with_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install randomuser
import randomuser
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()
some_list = r.generate_users(100)
some_list

# %%
name = r.get_full_name()
for user in some_list:
    print(user.get_full_name()," ",user.get_dob()," ",user.get_email()," ",user.get_nat())
# Out:
# Isabell Siebert   1977-05-21T23:59:59.593Z   isabell.siebert@example.com   DE
# Brittany Lee   1951-06-01T01:57:07.841Z   brittany.lee@example.com   AU
# Mariano Vazquez   1998-01-31T10:11:43.862Z   mariano.vazquez@example.com   ES
# Ava Peters   1971-05-10T18:58:17.600Z   ava.peters@example.com   GB
# Flora Aubert   1959-02-25T01:01:32.762Z   flora.aubert@example.com   FR
# Ceylan Başoğlu   1969-11-07T01:29:45.802Z   ceylan.basoglu@example.com   TR
# Sharon Hale   1982-01-09T09:45:44.905Z   sharon.hale@example.com   GB
# Furkan Van Donkelaar   1984-01-12T12:28:02.356Z   furkan.vandonkelaar@example.com   NL
# Brennan Green   1993-08-09T14:05:10.702Z   brennan.green@example.com   GB
# Aria Harris   1987-06-03T04:30:56.931Z   aria.harris@example.com   NZ
# Bianca Fernandez   1954-03-11T09:16:06.280Z   bianca.fernandez@example.com   CH
# Ayşe Beşok   1955-05-19T23:53:53.283Z   ayse.besok@example.com   TR
# Nelli Luoma   1962-05-31T16:35:22.303Z   nelli.luoma@example.com   FI
# ...

# %%
for user in some_list:
  print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/45.jpg
# https://randomuser.me/api/portraits/women/22.jpg
# https://randomuser.me/api/portraits/men/0.jpg
# https://randomuser.me/api/portraits/women/73.jpg
# https://randomuser.me/api/portraits/women/60.jpg
# https://randomuser.me/api/portraits/women/47.jpg
# https://randomuser.me/api/portraits/women/26.jpg
# https://randomuser.me/api/portraits/men/80.jpg
# https://randomuser.me/api/portraits/men/65.jpg
# https://randomuser.me/api/portraits/women/70.jpg
# https://randomuser.me/api/portraits/women/84.jpg
# https://randomuser.me/api/portraits/women/34.jpg
# https://randomuser.me/api/portraits/women/65.jpg
# https://randomuser.me/api/portraits/men/61.jpg
# https://randomuser.me/api/portraits/men/77.jpg
# https://randomuser.me/api/portraits/men/55.jpg
# https://randomuser.me/api/portraits/women/6.jpg
# https://randomuser.me/api/portraits/men/22.jpg
# https://randomuser.me/api/portraits/women/96.jpg
# ...
